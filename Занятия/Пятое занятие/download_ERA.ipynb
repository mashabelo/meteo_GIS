# %%
#!/usr/bin/env python
from ecmwfapi import ECMWFDataServer
    
server = ECMWFDataServer()
    
server.retrieve({
    'stream'    : "oper", 
    'levtype'   : "sfc",
    'param'     : "167.128/228.128",
    'dataset'   : "interim",
    'grid'      : "0.125/0.125", # кратность сетки в долях градуса
    'step'      : "3", # шаг моделируемых данных   
    'time'      : "00/12", # срок наблюдения
    'date'      : "1979-01-01/to/1979-01-30", # период наблюдений
    'type'      : "fc", # fc - forecast, an - analysis. Некоторые данные являются только прогнозными величинами
    #если step != 0, то тип - fc
    'class'     : "ei",
    'area'      : "61/27/58/32", # N/W/S/E область данных
    'format'    : "netcdf", # формат данных. По умолчанию - GRIB
    'target'    : "interim_STEP_3.nc" # файл сохранится там же, где расположен выполняемый скрипт
 })


# server.retrieve({
#     'stream'    : "oper", 
#     'levtype'   : "sfc",
#     'param'     : "167.128",
#     'dataset'   : "interim",
#     'step'      : "0", # шаг моделируемых данных
#     'grid'      : "0.125/0.125", # кратность сетки в долях градуса
#     'time'      : "00/06/12/18", # срок наблюдения
#     'date'      : "1979-01-01/to/1979-01-01",
#     'type'      : "an", # fc - forecast, an - analysis. Некоторые данные являются только прогнозными величинами
#     #если step != 0, то тип - fc
#     'class'     : "ei",
#     'area'      : "61/27/58/32", # "61/28/31/59" N/W/S/E область данных
#     'format'    : "netcdf", # формат данных. По умолчанию - GRIB
#     'target'    : "interim_STEP_12.nc" # файл сохранится там же, где расположен исполняемый скрипт
#  })
# Out:
# 2019-11-12 10:03:11 ECMWF API python library 1.5.4
# 2019-11-12 10:03:11 ECMWF API at https://api.ecmwf.int/v1
# 2019-11-12 10:03:12 Welcome Dima Abramov
# 2019-11-12 10:03:12 In case of problems, please check https://confluence.ecmwf.int/display/WEBAPI/Web+API+FAQ or contact servicedesk@ecmwf.int
# 2019-11-12 10:03:12 Request submitted
# 2019-11-12 10:03:12 Request id: 5dca592f2fd81c51e48f52a1
# 2019-11-12 10:03:12 Request is submitted
# 2019-11-12 10:03:14 Request is queued
# Calling 'nice mars /tmp/dc/b4/tmp-_marsh5kTsp.req'
# mars - WARN -
# mars - WARN - From 29 January 2019 10AM (UTC) MARS uses the interpolation
# mars - WARN - provided by the MIR library. For more details, see
# mars - WARN - https://confluence.ecmwf.int/display/UDOC/MARS+interpolation+with+MIR
# mars - WARN -
# PPDIR is /var/tmp/ppdir/x86_64
# mars - INFO   - 20191112.070314 - Welcome to MARS
# mars - INFO   - 20191112.070314 - MARS Client build stamp: 20190607111047
# mars - INFO   - 20191112.070314 - MARS Client version: 6.25.3
# mars - INFO   - 20191112.070314 - MIR version: 1.2.5
# mars - INFO   - 20191112.070314 - Using ecCodes version 2.12.6
# mars - INFO   - 20191112.070314 - Using odb_api version: 0.15.10 (file format version: 0.5)
# mars - INFO   - 20191112.070314 - Maximum retrieval size is 30.00 G
# retrieve,stream=oper,area=61/27/58/32,levtype=sfc,param=167.128/228.128,padding=0,step=3,grid=0.125/0.125,expver=0001,time=00/12,date=1979-01-01/to/1979-01-30,type=fc,class=eimars - WARN   - 20191112.070314 - For full resolution grid, it is recommended to use RESOL=AV to prevent any truncation before transformation
# mars - INFO   - 20191112.070314 - Automatic split by date is on
#
# mars - INFO   - 20191112.070314 - Processing request 1
#
# RETRIEVE,
#     CLASS      = EI,
#     TYPE       = FC,
#     STREAM     = OPER,
#     EXPVER     = 0001,
#     REPRES     = SH,
#     LEVTYPE    = SFC,
#     PARAM      = 167.128/228.128,
#     TIME       = 0000/1200,
#     STEP       = 3,
#     DOMAIN     = G,
#     RESOL      = AUTO,
#     AREA       = 61/27/58/32,
#     GRID       = 0.125/0.125,
#     PADDING    = 0,
#     DATE       = 
#
# mars - INFO   - 20191112.070314 - Web API request id: 5dca592f2fd81c51e48f52a1
# mars - INFO   - 20191112.070314 - Requesting 120 fields
# mars - INFO   - 20191112.070314 - Calling mars on 'marser', callback on 58651
# mars - INFO   - 20191112.070314 - Server task is 94 [marser]
# mars - INFO   - 20191112.070314 - Request cost: 120 fields, 20.4044 Mbytes online, nodes: mvr02 [marser]
# mars - INFO   - 20191112.070314 - Transfering 21395520 bytes
# 2019-11-12 10:03:19 Request is active
# mars - INFO   - 20191112.070318 - 120 fields retrieved from 'marser'
# mars - INFO   - 20191112.070318 - 120 fields have been interpolated
# mars - INFO   - 20191112.070318 - Request time:  wall: 4 sec  cpu: 1 sec
# mars - INFO   - 20191112.070318 -   Read from network: 20.40 Mbyte(s) in 2 sec  [10.40 Mbyte/sec]
# mars - INFO   - 20191112.070318 -   Visiting marser: wall: 4 sec
# mars - INFO   - 20191112.070318 -   Post-processing: wall: 1 sec cpu: 1 sec
# mars - INFO   - 20191112.070318 -   Writing to target file: 252.89 Kbyte(s) in < 1 sec [18.69 Mbyte/sec]
# mars - INFO   - 20191112.070318 - Memory used: 36.50 Mbyte(s)
# mars - INFO   - 20191112.070318 - No errors reported
# Process '['nice', 'mars', '/tmp/dc/b4/tmp-_marsh5kTsp.req']' finished
# Calling 'nice grib_to_netcdf /data/data02/scratch/fa/13/_mars-atls13-95e2cf679cd58ee9b4db4dd119a05a8d-beCVZa.grib -o /data/data04/scratch/e0/ef/_grib2netcdf-atls04-a562cefde8a29a7288fa0b8b7f9413f7-TeiNF3.nc -utime'
# grib_to_netcdf: Version 2.14.1
# grib_to_netcdf: Processing input file '/data/data02/scratch/fa/13/_mars-atls13-95e2cf679cd58ee9b4db4dd119a05a8d-beCVZa.grib'.
# grib_to_netcdf: Found 120 GRIB fields in 1 file.
# grib_to_netcdf: Ignoring key(s): method, type, stream, refdate, hdate
# grib_to_netcdf: Creating netCDF file '/data/data04/scratch/e0/ef/_grib2netcdf-atls04-a562cefde8a29a7288fa0b8b7f9413f7-TeiNF3.nc'
# grib_to_netcdf: NetCDF library version: 4.4.1.1 of Mar 14 2018 13:48:26 $
# grib_to_netcdf: Creating large (64 bit) file format.
# grib_to_netcdf: Defining variable 't2m'.
# grib_to_netcdf: Defining variable 'tp'.
# grib_to_netcdf: Done.
# Process '['nice', 'grib_to_netcdf', '/data/data02/scratch/fa/13/_mars-atls13-95e2cf679cd58ee9b4db4dd119a05a8d-beCVZa.grib', '-o', '/data/data04/scratch/e0/ef/_grib2netcdf-atls04-a562cefde8a29a7288fa0b8b7f9413f7-TeiNF3.nc', '-utime']' finished
# 2019-11-12 10:03:24 Request is complete
# 2019-11-12 10:03:24 Transfering 242.18 Kbytes into interim_STEP_3.nc
# 2019-11-12 10:03:24 From https://stream.ecmwf.int/data/atls04/data/data04/scratch/e0/ef/_grib2netcdf-atls04-a562cefde8a29a7288fa0b8b7f9413f7-TeiNF3.nc
# 2019-11-12 10:03:25 Transfer rate 904.628 Kbytes/s
